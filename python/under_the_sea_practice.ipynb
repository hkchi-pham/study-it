# %% [markdown]
# <a href="https://colab.research.google.com/github/hkchi-pham/study-it/blob/main/python/under_the_sea_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cài đặt thư viện Under the sea
# !pip install underthesea
# !pip install future scipy numpy scikit-learn==1.4.2 joblib
# Out:
# Requirement already satisfied: underthesea in /usr/local/lib/python3.11/dist-packages (6.8.4)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.11/dist-packages (from underthesea) (8.1.8)
# Requirement already satisfied: python-crfsuite>=0.9.6 in /usr/local/lib/python3.11/dist-packages (from underthesea) (0.9.11)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from underthesea) (3.9.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from underthesea) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from underthesea) (2.32.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from underthesea) (1.4.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from underthesea) (1.4.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from underthesea) (6.0.2)
# Requirement already satisfied: underthesea-core==1.0.4 in /usr/local/lib/python3.11/dist-packages (from underthesea) (1.0.4)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->underthesea) (2024.11.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->underthesea) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->underthesea) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->underthesea) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->underthesea) (2025.1.31)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->underthesea) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->underthesea) (1.13.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->underthesea) (3.5.0)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.13.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: scikit-learn==1.4.2 in /usr/local/lib/python3.11/dist-packages (1.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.4.2) (3.5.0)

# %% [markdown]
# # **Sentence Segmentation**
# Chia văn bản thành từng câu riêng biệt.

# %%
from underthesea import sent_tokenize

# Văn bản mẫu
with open("1.txt", "r", encoding="utf-8") as file:
    one_text = file.read()

with open("2.txt", "r", encoding="utf-8") as file:
    two_text = file.read()

with open("3.txt", "r", encoding="utf-8") as file:
    three_text = file.read()

with open("4.txt", "r", encoding="utf-8") as file:
    four_text = file.read()

with open("5.txt", "r", encoding="utf-8") as file:
    five_text = file.read()


one_text = one_text.replace("\n", ". ")
two_text = two_text.replace("\n", ". ")
three_text = three_text.replace("\n", ". ")
four_text = four_text.replace("\n", ". ")
five_text = five_text.replace("\n", ". ")
five_text
# Out:
# 'Chính trị. Tăng cường quan hệ song phương Việt - Hàn trong bối cảnh mới. 03 Tháng Mười Một 2015 | 18:14:02. (VOV5) - Ngày 3/11, tại Hà Nội, Viện Hàn lâm Khoa học xã hội Việt Nam phối hợp Học viện Ngoại giao Hàn Quốc tổ chức Tọa đàm khoa học “Cục diện chiến lược ở châu Á - Thái Bình Dương và phương thức tăng cường quan hệ song phương Việt - Hàn”.. Tại tọa đàm, các nhà khoa học đều nhấn mạnh việc tăng cường quan hệ giữa Việt Nam và Hàn Quốc trong bối cảnh mới. Tiến sĩ Hoàng Minh Hằng, Viện Nghiên cứu Đông Bắc Á, Viện Hàn lâm Khoa học xã hội Việt Nam, cho rằng Việt Nam và Hàn Quốc có tất cả các điều kiện để phát triển quan hệ song phương hơn nữa.. Để thúc đẩy mối quan hệ Việt - Hàn lên tầm cao mới, Phó Giáo sư Tiến sĩ Wooseon Choi nhấn mạnh việc tăng cường đối thoại chiến lược, hiểu biết lẫn nhau về tình hình chiến lược và những lợi ích chung đang thay đổi trong sự ổn định của khu vực.. Viện Hàn lâm Khoa học xã hội. Học viện Ngoại giao Hàn Quốc. tọa đàm khoa học. quan hệ Việt Hàn. Tin liên quan. Hàn Quốc hỗ trợ Việt Nam ứng dụng công nghệ thông tin trong giáo dục. Việt Nam mong muốn tăng cường hợp tác với Hàn Quốc trên tất cả các lĩnh vực. Quan hệ hợp tác Việt Nam - Hàn Quốc không ngừng phát triển mạnh m�
Nguyễn Tiến Long. Phó Trưởng ban Phó Cẩm Hoa -\xa0Đỗ Thái Hùng. Ban Đối ngoại, Đài Tiếng nói Việt Nam, 45 Bà Triệu, Hà Nội. ĐT: 024 38252070/ 024 38266809. Fax: 024 38266707. Email: vietkieuvov@gmail.com. vovworld@vov.org.vn. PHÒNG VIỆT KIỀU. LIÊN HỆ. JS Global Compulsory. '

# %%
# Tách câu
one_sentences = sent_tokenize(one_text)
two_sentences = sent_tokenize(two_text)
three_sentences = sent_tokenize(three_text)
four_sentences = sent_tokenize(four_text)
five_sentences = sent_tokenize(five_text)
print("Các câu đã được tách:")
sentences = [one_sentences,two_sentences,three_sentences,four_sentences,five_sentences]

for sentence in sentences:
  print(f"number of sentence: {len(sentence)}")
# Out:
# Các câu đã được tách:
# number of sentence: 90
# number of sentence: 88
# number of sentence: 107
# number of sentence: 94
# number of sentence: 90

# %%
for sentence in sentences:
  print("5 câu đầu tiên")
  print(sentence[:5])
  print("-"*50)
# Out:
# 5 câu đầu tiên
# ['Chính trị.', 'Tham vấn chính trị lần 2 cấp Bộ trưởng Ngoại giao Việt Nam – Lào.', '03 Tháng Mười Một 2015 | 19:47:01.', '(VOV5) - Việt Nam hết sức coi trọng và luôn dành ưu tiên cao nhất cho việc không ngừng củng cố và phát triển quan hệ đoàn kết đặc biệt, hợp tác toàn diện Việt Nam-Lào.. Quang cảnh buổi làm việc (Ảnh: TTXVN).', 'Hôm nay (03/11), tại Hà Nội, Phó Thủ tướng, Bộ trưởng Ngoại giao Việt Nam Phạm Bình Minh và Phó Thủ tướng, Bộ trưởng Ngoại giao Lào Thoonglun Sisulith đồng chủ trì cuộc họp Tham vấn chính trị thường niên lần thứ 2 cấp Bộ trưởng Ngoại giao giữa Bộ Ngoại giao hai nước.. Phát biểu khai mạc cuộc họp, Phó Thủ tướng, Bộ trưởng Ngoại giao Phạm Bình Minh khẳng định Việt Nam hết sức coi trọng và luôn dành ưu tiên cao nhất cho việc không ngừng củng cố và phát triển quan hệ đoàn kết đặc biệt, hợp tác toàn diện Việt Nam-Lào.']
# --------------------------------------------------
# 5 câu đầu tiên
# ['Chính trị.', 'Trưởng Ban dân vận Trung ương Hà Thị Khiết làm việc tại Đại sứ quán Việt Nam tại Campuchia.', '03 Tháng Mười Một 2015 | 19:44:10.', '(VOV5) - Trong khuôn khổ chuyến thăm và làm việc tại Vương quốc Campuchia từ ngày 03-07/11, chiều nay (03/11), Đoàn đại biểu Đảng Cộng sản Việt Nam do bà Hà Thị Khiết, Trưởng Ban Dân vận Trung ương gặp gỡ, làm việc với cán bộ, nhân viên Đại sứ quán, các cơ quan đại diện Việt Nam và đại diện cộng đồng người Campuchia gốc Việt tại Campuchia.. Phát biểu tại buổi làm việc, bà Hà Thị Khiết nhấn mạnh Đảng và Nhà nước Việt Nam luôn ghi nhận những đóng góp của cộng đồng người Campuchia gốc Việt qua các thời kỳ cách mạng.. Trưởng Ban Dân vận Trung ương Hà Thị Khiết mong muốn bà con tiếp tục đoàn kết, phát triển cộng đồng vững mạnh, đóng góp công sức vào sự phát triển của đất nước Campuchia cũng như góp phần củng cố, tăng cường quan hệ truyền thống, hợp tác tốt đẹp giữa Việt Nam và Campuchia.. Hà Thị Khiết.', 'cộng đồng người Việt.']
# --------------------------------------------------
# 5 câu đầu tiên
# ['Chính trị.', 'Quốc hội kết thúc phiên thảo luận về tình hình kinh tế-xã hội đất nước.', 'Ngọc Anh -.', '03 Tháng Mười Một 2015 | 18:57:03.', '(VOV5) - Các đại biểu Quốc hội đánh giá cao những nét nổi bật, những điểm sáng trên bức tranh kinh tế-xã hội 2015 với những dẫn chứng minh họa sát với tình hình thực tế, sinh động.. Những điểm sáng trên bức tranh kinh tế-xã hội 2015 (Ảnh minh họa).']
# --------------------------------------------------
# 5 câu đầu tiên
# ['Chính trị.', 'Lào đánh giá cao kết quả hợp tác với Việt Nam tại khu vực biên giới.', '03 Tháng Mười Một 2015 | 18:21:53.', '(VOV5) -\xa0Đánh giá trên được nêu trong buổi hội đàm tại thủ đô Vientiane với đoàn đại biểu Ban Chỉ đạo Tây Bắc, do Phó Trưởng Ban Lê Văn Lân dẫn đầu, đang có chuyến thăm và làm việc tại Lào.. Quang cảnh buổi hội đàm.', '(Ảnh: TTXVN).']
# --------------------------------------------------
# 5 câu đầu tiên
# ['Chính trị.', 'Tăng cường quan hệ song phương Việt - Hàn trong bối cảnh mới.', '03 Tháng Mười Một 2015 | 18:14:02.', '(VOV5) - Ngày 3/11, tại Hà Nội, Viện Hàn lâm Khoa học xã hội Việt Nam phối hợp Học viện Ngoại giao Hàn Quốc tổ chức Tọa đàm khoa học “Cục diện chiến lược ở châu Á - Thái Bình Dương và phương thức tăng cường quan hệ song phương Việt - Hàn”.. Tại tọa đàm, các nhà khoa học đều nhấn mạnh việc tăng cường quan hệ giữa Việt Nam và Hàn Quốc trong bối cảnh mới.', 'Tiến sĩ Hoàng Minh Hằng, Viện Nghiên cứu Đông Bắc Á, Viện Hàn lâm Khoa học xã hội Việt Nam, cho rằng Việt Nam và Hàn Quốc có tất cả các điều kiện để phát triển quan hệ song phương hơn nữa.. Để thúc đẩy mối quan hệ Việt - Hàn lên tầm cao mới, Phó Giáo sư Tiến sĩ Wooseon Choi nhấn mạnh việc tăng cường đối thoại chiến lược, hiểu biết lẫn nhau về tình hình chiến lược và những lợi ích chung đang thay đổi trong sự ổn định của khu vực.. Viện Hàn lâm Khoa học xã hội.']
# --------------------------------------------------

# %% [markdown]
# # **Word Segmentation**
# Chia văn bản thành từng từ riêng biệt.

# %%
from underthesea import word_tokenize
import re

def is_word(s):
    return re.sub(r"[^\w\s]", "", s)

one_wordtext = is_word(one_text)
one_words = word_tokenize(one_wordtext)
two_wordtext = is_word(two_text)
two_words = word_tokenize(two_wordtext)
three_wordtext = is_word(three_text)
three_words = word_tokenize(three_wordtext)
four_wordtext = is_word(four_text)
four_words = word_tokenize(four_wordtext)
five_wordtext = is_word(five_text)
five_words = word_tokenize(five_wordtext)


print("Các từ đã được tách:")
words = [one_words, two_words, three_words, four_words, five_words]
for word in words:
  print(f"number of word: {len(word)}")
# Out:
# Các từ đã được tách:
# number of word: 540
# number of word: 483
# number of word: 881
# number of word: 587
# number of word: 485

# %%
for word in words:
  print("20 từ đầu tiên")
  print(word[:20])
  print("-"*50)
# Out:
# 20 từ đầu tiên
# ['Chính trị', 'Tham vấn', 'chính trị', 'lần', '2', 'cấp', 'Bộ trưởng', 'Ngoại giao', 'Việt Nam', 'Lào', '03', 'Thang Mươi', 'Môt', '2015', '194701', 'VOV5', 'Việt Nam', 'hết sức', 'coi trọng', 'và']
# --------------------------------------------------
# 20 từ đầu tiên
# ['Chính trị', 'Trưởng', 'Ban', 'dân vận', 'Trung ương', 'Hà Thị Khiết', 'làm việc', 'tại', 'Đại sứ quán', 'Việt Nam', 'tại', 'Campuchia', '03', 'Thang Mươi', 'Môt', '2015', '194410', 'VOV5', 'Trong', 'khuôn khổ']
# --------------------------------------------------
# 20 từ đầu tiên
# ['Chính trị', 'Quốc hội', 'kết thúc', 'phiên', 'thảo luận', 'về', 'tình hình', 'kinh tếxã', 'hội', 'đất nước', 'Ngọc Anh', '03', 'Thang Mươi', 'Môt', '2015', '185703', 'VOV5 Các', 'đại biểu', 'Quốc hội', 'đánh giá']
# --------------------------------------------------
# 20 từ đầu tiên
# ['Chính trị', 'Lào', 'đánh giá', 'cao', 'kết quả', 'hợp tác', 'với', 'Việt Nam', 'tại', 'khu vực', 'biên giới', '03', 'Thang Mươi', 'Môt', '2015', '182153', 'VOV5', 'Đánh giá', 'trên', 'được']
# --------------------------------------------------
# 20 từ đầu tiên
# ['Chính trị', 'Tăng cường', 'quan hệ', 'song phương', 'Việt Hàn', 'trong', 'bối cảnh', 'mới', '03', 'Thang Mươi', 'Môt', '2015', '181402', 'VOV5', 'Ngày', '311', 'tại', 'Hà Nội', 'Viện Hàn lâm', 'Khoa học xã hội']
# --------------------------------------------------

# %% [markdown]
# # **Text Normalization**
# Tiền xử lý văn bản, chuẩn hóa ký tự và định dạng

# %%
import re

def is_word(s):
    return re.sub(r"[^\w\s]", "", s)

one_normal = [is_word(text) for text in one_sentences]
two_normal = [is_word(text) for text in two_sentences]
three_normal = [is_word(text) for text in three_sentences]
four_normal = [is_word(text) for text in four_sentences]
five_normal = [is_word(text) for text in five_sentences]

print("Các câu đã được chuẩn hóa:")
sentence = [one_normal,two_normal,three_normal,four_normal, five_normal]
for sent in sentence:
  print('5 dòng đầu')
  print(sent[:5])
  print("-"*50)
# Out:
# Các câu đã được chuẩn hóa:
# 5 dòng đầu
# ['Chính trị', 'Tăng cường quan hệ song phương Việt  Hàn trong bối cảnh mới', '03 Thang Mươi Môt 2015  181402', 'VOV5  Ngày 311 tại Hà Nội Viện Hàn lâm Khoa học xã hội Việt Nam phối hợp Học viện Ngoại giao Hàn Quốc tổ chức Tọa đàm khoa học Cục diện chiến lược ở châu Á  Thái Bình Dương và phương thức tăng cường quan hệ song phương Việt  Hàn Tại tọa đàm các nhà khoa học đều nhấn mạnh việc tăng cường quan hệ giữa Việt Nam và Hàn Quốc trong bối cảnh mới', 'Tiến sĩ Hoàng Minh Hằng Viện Nghiên cứu Đông Bắc Á Viện Hàn lâm Khoa học xã hội Việt Nam cho rằng Việt Nam và Hàn Quốc có tất cả các điều kiện để phát triển quan hệ song phương hơn nữa Để thúc đẩy mối quan hệ Việt  Hàn lên tầm cao mới Phó Giáo sư Tiến sĩ Wooseon Choi nhấn mạnh việc tăng cường đối thoại chiến lược hiểu biết lẫn nhau về tình hình chiến lược và những lợi ích chung đang thay đổi trong sự ổn định của khu vực Viện Hàn lâm Khoa học xã hội']
# --------------------------------------------------

# %% [markdown]
# # **POS Tagging**
# Gắn nhãn từ loại (danh từ, động từ, tính từ, v.v.).

# %%
from underthesea import pos_tag


# Gắn nhãn từ loại
pos_one = pos_tag(one_text)
pos_two = pos_tag(two_text)
pos_three = pos_tag(three_text)
pos_four = pos_tag(four_text)
pos_five = pos_tag(five_text)

pos_tag = [pos_one, pos_two, pos_three, pos_four, pos_five]
print("Kết quả gắn nhãn từ loại:")
for pos in pos_tag:
  print(pos[:20])
  print("-"*50)
# Out:
# Kết quả gắn nhãn từ loại:
# [('Chính trị', 'N'), ('.', 'CH'), ('Tham vấn', 'N'), ('chính trị', 'N'), ('lần', 'N'), ('2', 'M'), ('cấp', 'N'), ('Bộ trưởng', 'N'), ('Ngoại giao', 'N'), ('Việt Nam', 'Np'), ('–', 'CH'), ('Lào', 'Np'), ('.', 'CH'), ('03', 'N'), ('Tháng Mười Một', 'Np'), ('2015', 'V'), ('| 19:47:01', 'N'), ('.', 'CH'), ('(', 'CH'), ('VOV5', 'Ny')]
# --------------------------------------------------
# [('Chính trị', 'N'), ('.', 'CH'), ('Trưởng', 'N'), ('Ban', 'N'), ('dân vận', 'V'), ('Trung ương', 'N'), ('Hà Thị Khiết', 'Np'), ('làm việc', 'V'), ('tại', 'E'), ('Đại sứ quán', 'N'), ('Việt Nam', 'Np'), ('tại', 'E'), ('Campuchia', 'Np'), ('.', 'CH'), ('03', 'N'), ('Tháng Mười Một', 'Np'), ('2015', 'V'), ('| 19:44:10', 'N'), ('.', 'CH'), ('(', 'CH')]
# --------------------------------------------------
# [('Chính trị', 'N'), ('.', 'CH'), ('Quốc hội', 'N'), ('kết thúc', 'V'), ('phiên', 'N'), ('thảo luận', 'V'), ('về', 'E'), ('tình hình', 'N'), ('kinh tế-xã', 'N'), ('hội', 'N'), ('đất nước', 'N'), ('.', 'CH'), ('Ngọc Anh', 'Np'), ('-', 'CH'), ('.', 'CH'), ('03', 'N'), ('Tháng Mười Một', 'Np'), ('2015', 'V'), ('| 18:57:03', 'N'), ('.', 'CH')]
# --------------------------------------------------
# [('Chính trị', 'N'), ('.', 'CH'), ('Lào', 'Np'), ('đánh giá', 'V'), ('cao', 'A'), ('kết quả', 'N'), ('hợp tác', 'V'), ('với', 'E'), ('Việt Nam', 'Np'), ('tại', 'E'), ('khu vực', 'N'), ('biên giới', 'N'), ('.', 'CH'), ('03', 'N'), ('Tháng Mười Một', 'Np'), ('2015', 'V'), ('| 18:21:53', 'N'), ('.', 'CH'), ('(', 'CH'), ('VOV5', 'Ny')]
# --------------------------------------------------
# [('Chính trị', 'N'), ('.', 'CH'), ('Tăng cường', 'V'), ('quan hệ', 'N'), ('song phương', 'N'), ('Việt', 'Np'), ('-', 'CH'), ('Hàn', 'Np'), ('trong', 'E'), ('bối cảnh', 'N'), ('mới', 'A'), ('.', 'CH'), ('03', 'N'), ('Tháng Mười Một', 'Np'), ('2015', 'V'), ('| 18:14:02', 'N'), ('.', 'CH'), ('(', 'CH'), ('VOV5', 'Ny'), (')', 'CH')]
# --------------------------------------------------

# %%
from itertools import count
from collections import Counter

select = ['N','V','A']

count_one = Counter(tag for one_text, tag in pos_one if tag in select)
count_two = Counter(tag for two_text, tag in pos_two if tag in select)
count_three = Counter(tag for three_text, tag in pos_three if tag in select)
count_four = Counter(tag for four_text, tag in pos_four if tag in select)
count_five = Counter(tag for five_text, tag in pos_five if tag in select)

count_tag = [count_one, count_two, count_three, count_four, count_five]
for count in count_tag:
  print(count)
  print("-"*50)
# Out:
# Counter({'N': 198, 'V': 112, 'A': 33})
# --------------------------------------------------
# Counter({'N': 172, 'V': 100, 'A': 21})
# --------------------------------------------------
# Counter({'N': 357, 'V': 224, 'A': 48})
# --------------------------------------------------
# Counter({'N': 207, 'V': 142, 'A': 31})
# --------------------------------------------------
# Counter({'N': 174, 'V': 102, 'A': 23})
# --------------------------------------------------

# %% [markdown]
# # **Chunking**
# Nhóm các từ thành cụm có ý nghĩa.

# %%
from underthesea import chunk



# Phân đoạn cụm từ
chunk_one = chunk(one_text)
chunk_two = chunk(two_text)
chunk_three = chunk(three_text)
chunk_four = chunk(four_text)
chunk_five = chunk(five_text)

chunks = [chunk_one, chunk_two, chunk_three, chunk_four, chunk_five]
print("Kết quả phân đoạn cụm từ:")
for chunk in chunks:
  print(chunk[:5])
  print("-"*50)
# Out:
# Kết quả phân đoạn cụm từ:
# [('Chính trị', 'N', 'B-NP'), ('.', 'CH', 'O'), ('Tham vấn', 'N', 'B-NP'), ('chính trị', 'N', 'B-NP'), ('lần', 'N', 'B-NP')]
# --------------------------------------------------
# [('Chính trị', 'N', 'B-NP'), ('.', 'CH', 'O'), ('Trưởng', 'N', 'B-NP'), ('Ban', 'N', 'B-NP'), ('dân vận', 'V', 'B-VP')]
# --------------------------------------------------
# [('Chính trị', 'N', 'B-NP'), ('.', 'CH', 'O'), ('Quốc hội', 'N', 'B-NP'), ('kết thúc', 'V', 'B-VP'), ('phiên', 'N', 'B-NP')]
# --------------------------------------------------
# [('Chính trị', 'N', 'B-NP'), ('.', 'CH', 'O'), ('Lào', 'Np', 'B-NP'), ('đánh giá', 'V', 'B-VP'), ('cao', 'A', 'B-AP')]
# --------------------------------------------------
# [('Chính trị', 'N', 'B-NP'), ('.', 'CH', 'O'), ('Tăng cường', 'V', 'B-VP'), ('quan hệ', 'N', 'B-NP'), ('song phương', 'N', 'B-NP')]
# --------------------------------------------------

# %% [markdown]
# # **Named Entity Recognition (NER)**
# Xác định thực thể tên (tên riêng, địa điểm, tổ chức, v.v.)

# %%
from underthesea import ner

def classify(text):
  label_list = {
        'LOC': 'Location',
        'PER': 'Person',
        'ORG': 'Organization'
    }
  ner_result = ner(text)

  entities = []
  for item in ner_result:
      if len(item) >= 4:
          word, _, _, tag = item
          clean_tag = tag[2:] if tag.startswith(("B-","I-")) else tag
          if clean_tag in label_list:
            entities.append((label_list[clean_tag], word))

  for entity_type, entity in entities:
      print(entity_type, ":", entity)

for text in [one_text, two_text, three_text, four_text, five_text]:
  print("-"*50)
  classify(text)
# Out:
# --------------------------------------------------
# Location : Tham vấn
# Location : chính trị
# Location : lần
# Location : 2
# Location : cấp
# Location : Bộ trưởng
# Location : Ngoại giao
# Location : Việt Nam
# Location : Lào
# Location : 03
# Location : Tháng Mười Một
# Location : Việt Nam
# Person : Việt Nam-Lào
# Location : Ảnh
# Location : :
# Location : TTXVN
# Location : Hà Nội
# Location : Ngoại giao
# Location : Việt Nam
# Location : Phạm Bình Minh
# Location : Lào
# Location : Thoonglun Sisulith
# Location : lần
# Location : thứ
# Location : 2
# Location : Bộ trưởng
# Location : Ngoại giao
# Location : giữa
# Location : Bộ
# Location : Ngoại giao
# Location : hai
# Location : Bộ trưởng
# Location : Ngoại giao
# Location : Phạm Bình Minh
# Location : Việt Nam
# Location : toàn diện
# Location : Việt Nam-Lào
# Location : Bộ trưởng
# Location : Ngoại giao
# Location : Phạm Bình Minh
# Organization : Bộ
# Location : Lào
# Location : Thoonglun Sisulith
# Organization : Bộ
# Location : Ngoại giao
# Location : Việt Nam
# Organization : Bộ
# Location : Lào
# Organization : Đảng
# Person : Phạm Bình Minh
# Location : Việt Nam
# Location : Lào
# Location : Campuchia
# Location : Đại sứ quán
# Location : Việt Nam
# Location : Lào
# Location : Hoa Kỳ
# Location : Việt Nam
# Location : Lào
# Location : thành phố
# Location : Cần Thơ
# Location : Đại sứ
# Location : Việt Nam
# Location : Việt Nam
# Person : Ủy
# Location : Dự án
# Location : Luật
# Location : Đại học
# Location : Cần Thơ
# Location : Dư Thu Trang
# Location : -
# Location : Sứ
# Location : Pháp
# Location : chùa
# Location : Bổ Đà
# Location : Hội thảo
# Location : One Asia
# Location : Hà Nội
# Location : Chủ tịch
# Location : nước
# Location : Trần Đại Quang
# Location : Thủ tướng
# Location : Nguyễn Xuân Phúc
# Person : Hoa Kỳ Al
# Person : Gore
# Location : Bộ trưởng
# Location : Ngoại giao
# Location : Phạm Bình Minh
# Location : Quốc vụ khanh
# Location : Ấn Độ
# Location : Vijay Kum
# Location : Trần Đại Quang
# Location : Hồ Sơ
# Location : Biển Đông
# Location : tư liệu
# Location : Hoàng Sa
# Location : Trường Sa
# Location : Việt Nam
# Location : Bắc Cạn
# Location : Hoàng Sa
# Location : ,
# Location : Trường Sa
# Location : Tuần lễ
# Location : Biển
# Location : Việt Nam
# Location : năm
# Location : 2018
# Location : Quảng Ninh
# Location : Trung Quốc
# Location : Việt Nam
# Person : Tỉnh
# Person : Hòa Bình
# Location : Hoàng Sa
# Location : ,
# Location : Trường Sa
# Location : Việt Nam
# Location : .
# Location : APEC
# Location : Chủ tịch
# Location : nước
# Location : Trần Đại Quang
# Location
# Location : Hoàng Sa
# Location : ,
# Location : Trường Sa
# Location : Việt Nam
# Location : .
# Location : APEC
# Location : Chủ tịch
# Location : nước
# Location : Trần Đại Quang
# Location : :
# Location : APEC
# Location : Việt Nam
# Person : APEC
# Location : Báo
# Location : Singapore
# Location : Việt Nam
# Location : gốm
# Location : chân dung
# Location : lãnh đạo
# Location : các
# Location : nền
# Location : kinh tế
# Location : APEC
# Person : APEC
# Location : vị thế
# Location : Việt Nam
# Organization : Nga
# Location : châu Á-Thái
# Location : Bình Dương
# Location : kết quả
# Location : Tuần lễ
# Location : Cấp
# Location : APEC
# Person : VOVGT-Ha Noi
# Location : VOVGT-TP
# Location : Việt
# Location : Hà Nội
# Location : Việt Nam
# Person : VOV
# Location : Việt Nam
# Person : VOV.
# Person : Language
# Person : English
# Location : Vietnamese
# Location : Chinese
# Location : French
# Location : German
# Location : Indonesian
# Location : Japanese
# Location : Khmer
# Location : Korean
# Location : Laotian
# Location : Russian
# Location : .
# Location : Spanish
# Location : GP
# Location : -
# Location : BTTTT
# Location : Trưởng
# Location : ban
# Location : Nguyễn Tiến Long
# Location : Trưởng
# Location : ban
# Location : Phó
# Location : Cẩm Hoa
# Location : -
# Location : Đỗ Thái Hùng
# Location : Đài
# Location : Tiếng nói
# Location : Việt Nam
# Location : 45
# Location : Bà Triệu
# Location : Hà Nội
# Location : vovworld@vov.org.vn. PHÒNG
# Location : VIỆT KIỀU
# Location : LIÊN HỆ
# Person : JS
# Person : Global Compulsory
# --------------------------------------------------
# Location : tình hình
# Location : kinh tế-xã
# Location : hội
# Location : đất nước
# Location : .
# Location : Ngọc Anh
# Location : 03
# Location : Tháng Mười Một
# Location : Sáng
# Location : 3/11
# Location : Hà Nội
# Location : thứ
# Location : 10
# Location : năm
# Location : 2015
# Location : nông nghiệp
# Location : ..
# Location : Ông
# Location : Thào Hồng Sơn
# Location : đại biểu
# Location : Quốc hội
# Location : tỉnh
# Location : Hà Giang
# Location : kinh tế
# Location : trọng điểm
# Location : hiệu quả
# Location : nguồn
# Location : nhân lực
# Location : ..
# Location : Kết luận
# Location : 1
# Location : ngày
# Location : rưỡi
# Location : tình hình
# Location : kinh tế
# Location : xã hội
# Location : ,
# Location : Phó
# Location : Chủ tịch
# Location : Quốc hội
# Location : Nguyễn Thị Kim Ngân
# Location : ..
# Location : Phó
# Location : Chủ tịch
# Location : Quốc hội
# Location : Nguyễn Thị Kim Ngân
# Location : ..
# Location : Chiều
# Person : Trần Du Lịch
# Location : thành phố
# Location : Hồ Chí Minh
# Location : Thứ
# Location : ba
# Location : Việt Nam
# Location : ngân sách
# Location : Nhà nước
# Location : năm
# Location : 2015
# Location : ngân sách
# Location : Trung ương
# Location : năm
# Location : 2016
# Location : Quốc lộ
# Location : 1A
# Location : đường
# Location : Hồ Chí Minh
# Location : Tây Nguyên
# Location : ..
# Location : Ngọc Anh
# Location : thành phố
# Location : Cần Thơ
# Location : Đại sứ
# Location : Việt Nam
# Location : Việt Nam
# Person : Ủy
# Location : Dự án
# Location : Luật
# Location : Đại học
# Location : Cần Thơ
# Location : Dư Thu Trang
# Location : -
# Location : Sứ
# Location : Pháp
# Location : chùa
# Location : Bổ Đà
# Location : Hội thảo
# Location : One Asia
# Location : Hà Nội
# Location : Chủ tịch
# Location : nước
# Location : Trần Đại Quang
# Location